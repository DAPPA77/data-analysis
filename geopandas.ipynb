# %%
import geopandas as gpd

# %%
from zipfile import ZipFile

# %%
with ZipFile(file,"r") as zip:
    zip.printdir()
    zip.extractall()
# Out:
# File Name                                             Modified             Size
# us-airports.csv                                2022-05-14 10:09:06      5975892
# us-airports.vrt                                2022-05-14 10:09:06         3897
# us-airports.xml                                2022-05-14 10:09:06         6085
# us-airports.prj                                2022-05-14 10:09:06          302
# us-airports.csvt                               2022-05-14 10:09:06          470
# us-airports.txt                                2022-05-14 10:08:04        21531

# %%
pip install patool
# Out:
# ...
#
# ...
#      -------------------------------------- 77.5/77.5 kB 172.5 kB/s eta 0:00:00
# ...

# %%
import patoolib
a=patoolib.extract_archive("World_Countries.rar")
# Out:
# patool: Extracting World_Countries.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- "c:\Users\HP PC\Desktop\New folder\World_Countries.rar"
# patool:     with cwd=.\Unpack_4lqqd0k8
# patool: ... World_Countries.rar extracted to `World_Countries1' (multiple files in root).

# %%
world=gpd.read_file("C:\\Users\\HP PC\Desktop\\New folder\\World_Countries\\World_Countries.shp")

# %%
world.plot()
# Out:
# <AxesSubplot:>

# %%
w=gpd.read_file("C:\\Users\\HP PC\Desktop\\New folder\\World_Countries")

# %%
w.plot()
# Out:
# <AxesSubplot:>

# %%
w.head()
# Out:
#    COUNTRY                                           geometry
# 0  Nigeria  POLYGON ((-69.88223 12.41111, -69.94695 12.436...
# 1  Nigeria  MULTIPOLYGON (((-61.73889 17.54055, -61.75195 ...
# 2  Nigeria  POLYGON ((61.27656 35.60725, 61.29638 35.62853...
# 3  Nigeria  POLYGON ((-5.15213 30.18047, -5.13917 30.19236...
# 4  Nigeria  MULTIPOLYGON (((46.54037 38.87559, 46.49554 38...

# %%
c.loc[c["Name"]=="Bulbasaur"]

# %%
a=world.loc[world["COUNTRY"]=="United States"]

# %%
c=(world["COUNTRY"].str.contains("United"))

# %%
world["area"]=world.area
# Out:
# C:\Users\HP PC\AppData\Local\Temp\ipykernel_8284\2386470037.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   world["area"]=world.area

# %%
c[c==True]
# Out:
# 211    True
# 227    True
# 229    True
# Name: COUNTRY, dtype: bool

# %%
world.loc[229]
# Out:
# COUNTRY                                         United States
# geometry    (POLYGON ((-134.97500610351562 58.645828247070...
# Name: 229, dtype: object

# %%
c=world.crs

# %%
world.to_crs(epsg=3857,inplace=True)

# %%
world.plot(column="COUNTRY",cmap="jet")
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

# %%
a=pd.read_csv("us-airports.csv")

# %%
a[a["WKT"].str.contains("POLYGON")]
# Out:
# Empty DataFrame
# Columns: [WKT, LOCID, SITE_NO, FULLNAME, FAA_ST, LAN_FA_TY, EFF_DATE, FAA_REGION, FAA_DISTRI, STATE_NAME, ST_POSTAL, STFIPS, COUNTY_NAM, COUNTY_ST, CITY_NAME, OWNER_TYPE, FAC_USE, FAC_CYSTZP, ELEV, AERO_CHART, CBD_DIST, CBD_DIR, ACT_DATE, CERT_TYPE, FED_AGREE, INTERNATIO, CUST_LNDG, JOINT_USE, MIL_LNDG_R, MIL_INT, CNTL_TWR, S_ENG_GA, M_ENG_GA, JET_EN_GA, HELICOPTER, OPER_GLIDE, OPER_MIL, ULTRALIGHT, COMM_SERV, AIR_TAXI, LOCAL_OPS, ITIN_OPS, MIL_OPS, LATITUDE, LONGITUDE, VERSION, CY_06_ENP, GEOMETRY_X, GEOMETRY_Y]
# Index: []
#
# [0 rows x 49 columns]

# %%
geo=gpd.GeoDataFrame(a,geometry=gbd.points_from_xy(a["LONGITUDE"],a["LATITUDE"]))

# %%
import fiona
"well not text"
geo["geometry"].plot(markersize=1.5,figsize=(10,10))
geo.to_file(filename="usa_airport.shp",driver="ESRI Shapefile")
# Out:
# c:\Users\HP PC\Anaconda3\envs\geo_env\lib\site-packages\geopandas\io\file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %%
geo["geometry"].plot()
a.plot()
# Out:
# <AxesSubplot:>

# %%
"fire breakout map of us,it shows the fire outbreaks in usa and the airports locztion an outbreak has happened in only one airport"
fig,ax=plt.subplots()
geo["geometry"].plot(ax=ax,figsize=(20,20))
burns.plot(ax=ax,figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
world.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Untitled-1.ipynb Cell 29' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000034untitled?line=0'>1</a> a=pd.read_csv("C:\\Users\HP PC\\Desktop\\New folder\\file1.shp")
#
# File c:\Users\HP PC\Anaconda3\envs\geo_env\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/HP%20PC/Anaconda3/envs/geo_env/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/HP%20PC/Anaconda3/envs/geo_env/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
# ...

# %%
img1=Image.open("C:\\Users\HP PC\\Desktop\\New folder\\us.jpg")

# %%
img2=Image.open("C:\\Users\HP PC\\Desktop\\New folder\\usadata.jpg")

# %%
d=np.asarray(img1)
e=np.asarray(img2)

# %%
burns=gpd.read_file("C:\\Users\\HP PC\\Desktop\\New folder\\Monitoring_Trends_in_Burn_Severity%3A_Fire_Occurrence_Locations_and_Burned_Area_Boundaries.shp")

# %%
burns.plot()
# Out:
# <AxesSubplot:>

# %%
file1="npl.zip"
with ZipFile(file1,"r") as zip:
    zip.printdir()
    zip.extractall()
# Out:
# File Name                                             Modified             Size
# license.txt                                    2015-08-12 22:01:16          246
# NPL_adm0.cpg                                   2015-08-11 13:56:30            5
# NPL_adm0.csv                                   2015-08-11 15:51:32         1134
# NPL_adm0.dbf                                   2015-08-11 13:56:32         5685
# NPL_adm0.prj                                   2015-08-11 13:56:30          145
# NPL_adm0.shp                                   2015-08-11 13:56:30        92188
# NPL_adm0.shx                                   2015-08-11 13:56:30          108
# NPL_adm1.cpg                                   2015-08-11 14:20:18            5
# NPL_adm1.csv                                   2015-08-11 16:23:42         1559
# NPL_adm1.dbf                                   2015-08-11 14:20:18         2692
# NPL_adm1.prj                                   2015-08-11 14:20:18          145
# ...

# %%
import pandas as pd
a=pd.read_html("https://www.citypopulation.de/php/nigeria-admin.php")
for i in a:
    print(i)
i.to_excel("population.xlsx")
# Out:
#               Name                 Status PopulationCensus1991-11-26  \
# 0             Abia                  State                    2338487
# 1        Aba North  Local Government Area                      86331
# 2        Aba South  Local Government Area                     413852
# 3        Arochukwu  Local Government Area                      97800
# 4            Bende  Local Government Area                     132271
# ..             ...                    ...                        ...
# 808       Shinkafi  Local Government Area                        ...
# 809  Talata Mafara  Local Government Area                     138844
# 810          Tsafe  Local Government Area                     163512
# 811          Zurmi  Local Government Area                     176683
# 812        Nigeria       Federal Republic                   88992220
#
#      PopulationCensus2006-03-21  PopulationProjection2016-03-21 Unnamed: 5
# ...

# %%
import pandas as pd

# %%
pip install lxml
# Out:
# ...
#
# ...
#      ---------------------------------------- 3.6/3.6 MB 535.3 kB/s eta 0:00:00
# ...

# %%
i[i["Status"]=="State"]
# Out:
#             Name Status PopulationCensus1991-11-26  \
# 0           Abia  State                    2338487
# 18       Adamawa  State                    2102053
# 40     Akwa Ibom  State                    2409613
# 72       Anambra  State                    2796475
# 94        Bauchi  State                    2861887
# 115      Bayelsa  State                    1121693
# 124        Benue  State                    2753077
# 148        Borno  State                    2536003
# 176  Cross River  State                    1911297
# 195        Delta  State                    2590491
# 221       Ebonyi  State                    1029312
# 235          Edo  State                    2172005
# 254        Ekiti  State                    1535790
# 271        Enugu  State                    2125068
# 296        Gombe  State                    1489120
# 308          Imo  State                    2485635
# 336       Jigawa  State                    2875525
# ...

# %%
i.to_excel("C:\\Users\HP PC\'Desktop\\New folder\\pop.xlsx","r+")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\HP PC\Desktop\New folder\geopandas.ipynb Cell 40' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP%20PC/Desktop/New%20folder/geopandas.ipynb#ch0000039?line=0'>1</a> i.to_excel("C:\\Users\HP PC\'Desktop\\New folder\\pop.xlsx","r+")
#
# File c:\Users\HP PC\Anaconda3\envs\geo_env\lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    <a href='file:///c%3A/Users/HP%20PC/Anaconda3/envs/geo_env/lib/site-packages/pandas/core/generic.py?line=2331'>2332</a> from pandas.io.formats.excel import ExcelFormatter
# ...

# %%
pip install openpyxl
# Out:
# ...
#
# ...
#      ------------------------------------ 242.2/242.2 kB 345.6 kB/s eta 0:00:00
# ...

# %%
i
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\HP PC\Desktop\New folder\geopandas.ipynb Cell 42' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP%20PC/Desktop/New%20folder/geopandas.ipynb#ch0000041?line=0'>1</a> i
#
# NameError: name 'i' is not defined

# %%
import geopandas as gpd
import pandas as pd
import geopy

# %% [markdown]
# import foliun

# %%
import folium
from geopandas.tools import  geocode

# %%
data=pd.read_html("https://en.m.wikipedia.org/wiki/List_of_most_visited_palaces_and_monuments?fbclid=IwAR3TZsoFGRH2fwOumWSoJyOU7-i62vVwgRG_YbUdPYZUG6eKt4ejmMMiX5Y")
for i in data:
    print(i)
# Out:
#               National monuments by visitors per year                     \
#                                                  Name Country flag, city
# 0                                      Forbidden City            Beijing
# 1                                St. Peter's Basilica       Vatican City
# 2                                Palace of Versailles         Versailles
# 3                                    Lincoln Memorial   Washington, D.C.
# 4               Colosseum-Forum-Palatine Hill Circuit               Rome
# 5                                           Parthenon             Athens
# 6                                        Eiffel Tower              Paris
# 7                                           Taj Mahal               Agra
# 8                                   Cologne Cathedral            Cologne
# 9                                     Peterhof Palace   Saint Petersburg
# 10                                    Łazienki Palace             Warsaw
# ...

# %%
i.to_csv("wikipedia.csv",header=True)

# %%
a=pd.read_csv("wikipedia.csv")

# %%
a.head()
# Out:
#    Unnamed: 0 National monuments by visitors per year  \
# 0         NaN                                    Name
# 1         0.0                          Forbidden City
# 2         1.0                    St. Peter's Basilica
# 3         2.0                    Palace of Versailles
# 4         3.0                        Lincoln Memorial
#
#   National monuments by visitors per year.1  \
# 0                        Country flag, city
# 1                                   Beijing
# 2                              Vatican City
# 3                                Versailles
# 4                          Washington, D.C.
#
#   National monuments by visitors per year.2  \
# 0                         Visitors per year
# 1                               17,000,000+
# 2                                  11000000
# 3                                   8100000
# 4                                   7804683
#
#   National monuments by visitors per year.3  \
# 0                             Year reported
# ...

# %%
a=a.iloc[:,[1,2,3]]

# %%
a.loc[1]
# Out:
# Unnamed: 0                                              0.0
# National monuments by visitors per year      Forbidden City
# National monuments by visitors per year.1           Beijing
# National monuments by visitors per year.2       17,000,000+
# National monuments by visitors per year.3           2018[1]
# National monuments by visitors per year.4               NaN
# Name: 1, dtype: object

# %%
y=[]
for i in range(10):
    y.append(i)
print(y[:3])
# Out:
# [0, 1, 2]

# %%
a.columns=["a","b","c"]

# %%
a.drop(0,inplace=True)

# %%
a
# Out:
#                                                     a                 b  \
# 1                                      Forbidden City           Beijing
# 2                                St. Peter's Basilica      Vatican City
# 3                                Palace of Versailles        Versailles
# 4                                    Lincoln Memorial  Washington, D.C.
# 5               Colosseum-Forum-Palatine Hill Circuit              Rome
# 6                                           Parthenon            Athens
# 7                                        Eiffel Tower             Paris
# 8                                           Taj Mahal              Agra
# 9                                   Cologne Cathedral           Cologne
# 10                                    Peterhof Palace  Saint Petersburg
# 11                                    Łazienki Palace            Warsaw
# 12                          Vietnam Veterans Memorial  Washington, D.C.
# ...

# %%
info=geocode("The Statue of Liberty",provider="photon")

# %%
info
# Out:
#                      geometry  \
# 0  POINT (-74.04455 40.68925)
#
#                                              address
# 0  Statue of Liberty, Flagpole Plaza, 10004, Flag...

# %%
info.plot()
# Out:
# <AxesSubplot:>

# %%
a
y=[]
for i in a["a"]:
    y.append(i)
for b in (y):
    info=geocode(b,provider="photon")
    a["new"]=info["address"]
    
    
    info=geocode(b,provider="photon")

# %%
a
# Out:
#                                                     a                 b  \
# 1                                      Forbidden City           Beijing
# 2                                St. Peter's Basilica      Vatican City
# 3                                Palace of Versailles        Versailles
# 4                                    Lincoln Memorial  Washington, D.C.
# 5               Colosseum-Forum-Palatine Hill Circuit              Rome
# 6                                           Parthenon            Athens
# 7                                        Eiffel Tower             Paris
# 8                                           Taj Mahal              Agra
# 9                                   Cologne Cathedral           Cologne
# 10                                    Peterhof Palace  Saint Petersburg
# 11                                    Łazienki Palace            Warsaw
# 12                          Vietnam Veterans Memorial  Washington, D.C.
# ...

# %%
for index,row in a.iterrows():
    try:
        print(row["a"])
        info=geocode(str(row["a"]),provider="photon")
        a.loc[int(index),"address"]=info["address"].loc[0]
        a.loc[int(index),"lon"]=info["geometry"].loc[0].x
        a.loc[int(index),"lat"]=info["geometry"].loc[0].y
        
    except IndexError:
        print("not found")
# Out:
# Forbidden City
# St. Peter's Basilica
# Palace of Versailles
# Lincoln Memorial
# Colosseum-Forum-Palatine Hill Circuit
# not found
# Parthenon
# Eiffel Tower
# Taj Mahal
# Cologne Cathedral
# Peterhof Palace
# Łazienki Palace
# Vietnam Veterans Memorial
# World War II Memorial
# Independence National Historical Park
# Sagrada Família
# Statue of Liberty National Monument
# Teotihuacán
# Mysore Palace
# Tsarskoe Selo State Museum-Reserve
# not found
# Pompeii
# Wilanów Palace
# Schönbrunn Palace
# Kazan Kremlin
# Tower of London
# Alhambra
# Chichén Itzá
# Topkapı Palace
# Chapultepec Castle
# Ciudad de las Artes y las Ciencias
# Statue of Unity
# Moscow Kremlin
# Battle of Stalingrad State Museum-Reserve
# not found
# Tulum
# Auschwitz-Birkenau Memorial and Museum
# not found
# Edinburgh Castle
# Mosque–Cathedral of Córdoba
# not found
# Royal Alcázar of Seville
# Wawel Castle
# Arc de Triomphe
# Royal Palace of Madrid
# Neuschwanstein Castle
# Machu Picchu
# ...

# %%
import pandas as pd
a.to_csv("a.csv")

# %%
pd.read_csv("a.csv")
# Out:
#     Unnamed: 0                                                  a  \
# 0            1                                     Forbidden City
# 1            2                               St. Peter's Basilica
# 2            3                               Palace of Versailles
# 3            4                                   Lincoln Memorial
# 4            5              Colosseum-Forum-Palatine Hill Circuit
# 5            6                                          Parthenon
# 6            7                                       Eiffel Tower
# 7            8                                          Taj Mahal
# 8            9                                  Cologne Cathedral
# 9           10                                    Peterhof Palace
# 10          11                                    Łazienki Palace
# 11          12                          Vietnam Veterans Memorial
# 12          13                              World War II Memorial
# ...

# %%
for i in info["geometry"]:
    print(i)
# Out:
# GEOMETRYCOLLECTION EMPTY

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\HP PC\Anaconda3\envs\geo_env\lib\site-packages\pandas\core\indexes\range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     <a href='file:///c%3A/Users/HP%20PC/Anaconda3/envs/geo_env/lib/site-packages/pandas/core/indexes/range.py?line=383'>384</a> try:
# --> <a href='file:///c%3A/Users/HP%20PC/Anaconda3/envs/geo_env/lib/site-packages/pandas/core/indexes/range.py?line=384'>385</a>     return self._range.index(new_key)
#     <a href='file:///c%3A/Users/HP%20PC/Anaconda3/envs/geo_env/lib/site-packages/pandas/core/indexes/range.py?line=385'>386</a> except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
type(info)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
world
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\HP PC\Desktop\New folder\geopandas.ipynb Cell 68' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP%20PC/Desktop/New%20folder/geopandas.ipynb#ch0000067?line=0'>1</a> world
#
# NameError: name 'world' is not defined

# %%
w.loc[0]
# Out:
# COUNTRY                                   Aruba (Netherlands)
# geometry    POLYGON ((-69.88223266601562 12.41110992431640...
# Name: 0, dtype: object

# %%
w["COUNTRY"].loc[0]
# Out:
# 'Aruba (Netherlands)'

# %%
w
# Out:
#                    COUNTRY                                           geometry
# 0      Aruba (Netherlands)  POLYGON ((-69.88223 12.41111, -69.94695 12.436...
# 1      Antigua and Barbuda  MULTIPOLYGON (((-61.73889 17.54055, -61.75195 ...
# 2              Afghanistan  POLYGON ((61.27656 35.60725, 61.29638 35.62853...
# 3                  Algeria  POLYGON ((-5.15213 30.18047, -5.13917 30.19236...
# 4               Azerbaijan  MULTIPOLYGON (((46.54037 38.87559, 46.49554 38...
# ..                     ...                                                ...
# 247            South Sudan  POLYGON ((34.21807 9.96458, 34.20722 9.90500, ...
# 248              Indonesia  MULTIPOLYGON (((123.21846 -10.80917, 123.19832...
# 249             East Timor  MULTIPOLYGON (((124.41824 -9.30010, 124.40446 ...
# 250  Curacao (Netherlands)  POLYGON ((-68.96556 12.19889, -68.91196 12.181...
# 251  Bonaire (Netherlands)  POLYGON ((-68.19736 12.22264, -68.19292 12.207...
#
# [252 rows x 2 columns]

# %%
w
# Out:
#                    COUNTRY                                           geometry
# 0      Aruba (Netherlands)  POLYGON ((-69.88223 12.41111, -69.94695 12.436...
# 1      Antigua and Barbuda  MULTIPOLYGON (((-61.73889 17.54055, -61.75195 ...
# 2              Afghanistan  POLYGON ((61.27656 35.60725, 61.29638 35.62853...
# 3                  Algeria  POLYGON ((-5.15213 30.18047, -5.13917 30.19236...
# 4               Azerbaijan  MULTIPOLYGON (((46.54037 38.87559, 46.49554 38...
# ..                     ...                                                ...
# 247            South Sudan  POLYGON ((34.21807 9.96458, 34.20722 9.90500, ...
# 248              Indonesia  MULTIPOLYGON (((123.21846 -10.80917, 123.19832...
# 249             East Timor  MULTIPOLYGON (((124.41824 -9.30010, 124.40446 ...
# 250  Curacao (Netherlands)  POLYGON ((-68.96556 12.19889, -68.91196 12.181...
# 251  Bonaire (Netherlands)  POLYGON ((-68.19736 12.22264, -68.19292 12.207...
#
# [252 rows x 2 columns]

# %%
#"geoplot of most visited monuments in the world from this you can see that africa has the least visits,and eurasia (europe and asia are leading)"
from matplotlib import pyplot as plt
fig,ax=plt.subplots()
w.plot(ax=ax)
geo.plot(ax=ax,color='black')
# Out:
# <AxesSubplot:>

# %%
geo=gpd.GeoDataFrame(a,geometry=gpd.points_from_xy(a["lon"],a["lat"]))

# %%
geo
# Out:
#                                                     a                 b  \
# 1                                      Forbidden City           Beijing
# 2                                St. Peter's Basilica      Vatican City
# 3                                Palace of Versailles        Versailles
# 4                                    Lincoln Memorial  Washington, D.C.
# 5               Colosseum-Forum-Palatine Hill Circuit              Rome
# 6                                           Parthenon            Athens
# 7                                        Eiffel Tower             Paris
# 8                                           Taj Mahal              Agra
# 9                                   Cologne Cathedral           Cologne
# 10                                    Peterhof Palace  Saint Petersburg
# 11                                    Łazienki Palace            Warsaw
# 12                          Vietnam Veterans Memorial  Washington, D.C.
# ...

# %%
import folium

# %%
geo.dropna(inplace=True)

# %%
map=folium.Map(tiles='OpenStreetMap')
for index,row in geo.iterrows():
    folium.Marker([row["lat"],row["lon"]],popup=row["a"]).add_to(map)
map.save("monument.html")

# %%
geo
# Out:
#                                         a                 b            c  \
# 1                          Forbidden City           Beijing  17,000,000+
# 2                    St. Peter's Basilica      Vatican City     11000000
# 3                    Palace of Versailles        Versailles      8100000
# 4                        Lincoln Memorial  Washington, D.C.      7804683
# 6                               Parthenon            Athens      7200000
# 7                            Eiffel Tower             Paris      7000000
# 8                               Taj Mahal              Agra      6532366
# 9                       Cologne Cathedral           Cologne      6000000
# 10                        Peterhof Palace  Saint Petersburg      5245900
# 11                        Łazienki Palace            Warsaw      4966858
# 12              Vietnam Veterans Memorial  Washington, D.C.      4719148
# 13                  World War II Memorial  Washington, D.C.      4652865
# ...

# %% [markdown]
# #### mineral datatset

# %% [markdown]
# ### data analysis

# %%
file="minerals_data.zip"
with ZipFile(file,"r") as zip:
    zip.printdir()
    zip.extractall()
# Out:
# File Name                                             Modified             Size
# mrds-trim.prj                                  2018-04-06 15:48:28          256
# mrds-trim.shp                                  2018-04-06 15:48:28      8529796
# mrds-trim.shx                                  2018-04-06 15:48:28      2437156
# mrds-trim.dbf                                  2018-04-06 15:48:28    163282945
# mrds-trim.lyr                                  2016-02-12 10:35:02        64512
# mrds.met                                       2017-04-24 10:00:14       141930

# %%
import geopandas as gpd
minerals=gpd.read_file("C:\\Users\\HP PC\\Desktop\\New folder\\mrds-trim.shp")

# %%
minerals
# Out:
#           DEP_ID            SITE_NAME       DEV_STAT  \
# 0       10000001     Lookout Prospect     Occurrence
# 1       10000002  Lucky Find Prospect     Occurrence
# 2       10000003  Mccullough Prospect     Occurrence
# 3       10000004      Lucky Jim Claim     Occurrence
# 4       10000005   Matilda Occurrence     Occurrence
# ...          ...                  ...            ...
# 304627  60001855       Cuale District       Producer
# 304628  60001856             Agalteca       Prospect
# 304629  60001857     La Libertad Area       Producer
# 304630  60001858        Santo Domingo  Past Producer
# 304631  10193016           Gravel Pit  Past Producer
#
#                                                       URL  \
# 0       https://mrdata.usgs.gov/mrds/show-mrds.php?dep...
# 1       https://mrdata.usgs.gov/mrds/show-mrds.php?dep...
# 2       https://mrdata.usgs.gov/mrds/show-mrds.php?dep...
# 3       https://mrdata.usgs.gov/mrds/show-mrds.php?dep...
# ...

# %%
import statistics as s
import numpy as np
s.mode(minerals["CODE_LIST"])
# Out:
# 'SDG'

# %%
count=0
for i in minerals["CODE_LIST"]:
    if i=="SDG":
        count+=1
print(count)
# Out:
# 45546

# %%
minerals.isna().sum()
# Out:
# DEP_ID        0
# SITE_NAME     0
# DEV_STAT      0
# URL           0
# CODE_LIST    88
# geometry      0
# dtype: int64

# %%
"for this situation it is best to use drop na for this as minerals value is missing"
# Out:
# 'for this situation it is best to use drop na for this as minerals value is missing'

# %%
minerals["CODE_LIST"].dropna(inplace=True)

# %%
minerals[minerals["SITE_NAME"]=="Unknown"]
# Out:
#           DEP_ID SITE_NAME       DEV_STAT  \
# 584     10000587   Unknown  Past Producer
# 3546    10003556   Unknown     Occurrence
# 3688    10003698   Unknown     Occurrence
# 8168    10008289   Unknown     Occurrence
# 9689    10009986   Unknown  Past Producer
# ...          ...       ...            ...
# 302088  10400265   Unknown       Prospect
# 302089  10400266   Unknown       Prospect
# 302090  10400268   Unknown       Prospect
# 302205  10400408   Unknown       Prospect
# 303220  60000434   Unknown     Occurrence
#
#                                                       URL   CODE_LIST  \
# 584     https://mrdata.usgs.gov/mrds/show-mrds.php?dep...          AU
# 3546    https://mrdata.usgs.gov/mrds/show-mrds.php?dep...       AG AU
# 3688    https://mrdata.usgs.gov/mrds/show-mrds.php?dep...          MN
# 8168    https://mrdata.usgs.gov/mrds/show-mrds.php?dep...   FE TI_M V
# 9689    https://mrdata.usgs.gov/mrds/show-mrds.php?dep...  AU AG PB F
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\HP PC\Desktop\New folder\geopandas.ipynb Cell 92' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/HP%20PC/Desktop/New%20folder/geopandas.ipynb#ch0000092?line=2'>3</a> fig,ax=plt.subplots()
#       <a href='vscode-notebook-cell:/c%3A/Users/HP%20PC/Desktop/New%20folder/geopandas.ipynb#ch0000092?line=3'>4</a> world.plot(ax=ax)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP%20PC/Desktop/New%20folder/geopandas.ipynb#ch0000092?line=4'>5</a> minerals.plot(hue=minerals["CODE_LIST"],ax=ax)
#
# File c:\Users\HP PC\Anaconda3\envs\geo_env\lib\site-packages\geopandas\plotting.py:950, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     <a href='file:///c%3A/Users/HP%20PC/Anaconda3/envs/geo_env/lib/site-packages/geopandas/plotting.py?line=947'>948</a> kind = kwargs.pop("kind", "geo")
# ...

# %%
import geoplot

# %%
import mapclassify as mc

# %%
ax=geoplot.webmap(minerals["geometry"],projection=gcrs.WebMercator())
geoplot.pointplot(minerals,ax=ax)
# Out:
# <GeoAxesSubplot:>

# %%
import geoplot.crs as gcrs
minerals
# Out:
#           DEP_ID            SITE_NAME       DEV_STAT  \
# 0       10000001     Lookout Prospect     Occurrence
# 1       10000002  Lucky Find Prospect     Occurrence
# 2       10000003  Mccullough Prospect     Occurrence
# 3       10000004      Lucky Jim Claim     Occurrence
# 4       10000005   Matilda Occurrence     Occurrence
# ...          ...                  ...            ...
# 304627  60001855       Cuale District       Producer
# 304628  60001856             Agalteca       Prospect
# 304629  60001857     La Libertad Area       Producer
# 304630  60001858        Santo Domingo  Past Producer
# 304631  10193016           Gravel Pit  Past Producer
#
#                                                       URL  \
# 0       https://mrdata.usgs.gov/mrds/show-mrds.php?dep...
# 1       https://mrdata.usgs.gov/mrds/show-mrds.php?dep...
# 2       https://mrdata.usgs.gov/mrds/show-mrds.php?dep...
# 3       https://mrdata.usgs.gov/mrds/show-mrds.php?dep...
# ...

# %%
# Out:
# Lookout Prospect
# Lucky Find Prospect
# Mccullough Prospect
# Lucky Jim Claim
# Matilda Occurrence
# Marion Prospect
# Marble Heart Prospect
# Morning Star Prospect
# Monday Prospect
# Miller Brothers Claim
# Midnight Sun Prospect
# Moonshine Occurrence
# Moonshine Prospect
# Edith M. Prospect
# Jumbo Prosect
# Hula Hula Claim
# Unnamed Occurrence
# Unnamed Occurrance
# Hatchet Occurrence
# Beauty
# Hole In the Wall Prospects
# Brown and Metzdorf Prospect
# Copper King Prospect
# Unnamed Occurrence
# Gould Prospect
# Gladstone Prospect
# Hetta Mountain Prospects
# Unnamed Occurrence
# Coleman
# Lime Point Barite
# Constitution Prospect
# Unnamed Occurrence
# Unnamed Occurrence
# Cutter Prospect
# Dama Prospects
# Dew Drop Prospect
# Fortune Prospect
# Flagstaff Mining Co.
# Golden Fleece Mining Co.
# Buckhorn Claims
# Keystone Prospect
# Ketchikan Copper Co.
# Helm Bay King Mining Co.
# Moonshine Mine
# Cascade Mine
# Unnamed Prospect
# Unnamed Occurrence
# House Occurrence
# ...

# %%
minerals=folium.Map(tiles='OpenStreetMap')
for index,row in minerals.iterrows():
    folium.Marker([row["lat"],row["lon"]],popup=row["SITE_NAME"]).add_to(minerals)
minerals.save("minerals_location.html")

# %%
"big data taking a sample for the test"
minerals_sample=minerals.loc[0:10,:]

# %%
minerals_sample
# Out:
#       DEP_ID              SITE_NAME    DEV_STAT  \
# 0   10000001       Lookout Prospect  Occurrence
# 1   10000002    Lucky Find Prospect  Occurrence
# 2   10000003    Mccullough Prospect  Occurrence
# 3   10000004        Lucky Jim Claim  Occurrence
# 4   10000005     Matilda Occurrence  Occurrence
# 5   10000006        Marion Prospect  Occurrence
# 6   10000007  Marble Heart Prospect  Occurrence
# 7   10000008  Morning Star Prospect  Occurrence
# 8   10000009        Monday Prospect  Occurrence
# 9   10000010  Miller Brothers Claim  Occurrence
# 10  10000011  Midnight Sun Prospect  Occurrence
#
#                                                   URL CODE_LIST  \
# 0   https://mrdata.usgs.gov/mrds/show-mrds.php?dep...  CU AU AG
# 1   https://mrdata.usgs.gov/mrds/show-mrds.php?dep...     CU AU
# 2   https://mrdata.usgs.gov/mrds/show-mrds.php?dep...  CU ZN AU
# 3   https://mrdata.usgs.gov/mrds/show-mrds.php?dep...  AU PB CU
# ...

# %%
for index,row in minerals_sample.iterrows():
    try:
        print(row["SITE_NAME"])
        info=geocode(str(row["SITE_NAME"]),provider="photon")
        minerals_sample.loc[int(index),"address"]=info["address"].loc[0]
        minerals_sample.loc[int(index),"lon"]=info["geometry"].loc[0].x
        minerals_sample.loc[int(index),"lat"]=info["geometry"].loc[0].y
        
    except IndexError:
        print("not found")
# Out:
# Lookout Prospect
# Lucky Find Prospect
# Mccullough Prospect
# Lucky Jim Claim
# Matilda Occurrence
# Marion Prospect
# Marble Heart Prospect
# Morning Star Prospect
# Monday Prospect
# Miller Brothers Claim
# Midnight Sun Prospect

# %%
minerals=folium.Map(tiles='OpenStreetMap')
for index,row in minerals_sample.iterrows():
    folium.Marker([row["lat"],row["lon"]],popup=row["SITE_NAME"]).add_to(minerals)
minerals.save("minerals_location.html")

# %%
https://github.com/DAPPA77/data-analysis.git
